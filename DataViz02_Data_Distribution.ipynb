# %% [markdown]
# <a href="https://colab.research.google.com/github/Wanita-8943/data_viz_2022/blob/main/DataViz02_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Scatter Plot

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1])

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %% [markdown]
# ##เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# ##ระบุสีให้แต่ละจุด

# %%
set (df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ### แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี (r g b c m y k w)

# %%
df2 = df.replace({'Iris-setosa':'r','Iris-versicolor':'g', 'Iris-virginica':'b'})

# %%
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])

# %% [markdown]
# ##เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ###ชื่อ maker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ###ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petel&sepal  length of different iris flowers');

# %% [markdown]
# ##ใช้ขนาดของ Marker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petel&sepal  length of different iris flowers');

# %% [markdown]
# ##ขยายขนาด Marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petel&sepal  length of different iris flowers');

# %% [markdown]
# ## ปรับความโปร่งใสของ Marker เพื่อให้มองเห็นจุดที่ถูกบัง (Bubble Chart)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50]) #ทำให้โปร่งแสงโดยใช้ alpha
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petel&sepal  length of different iris flowers');

# %% [markdown]
# ## เปลี่ยนหน้าตาของ Marker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='$\heartsuit$') #เปลี่ยนหน้าตาด้วย Marker
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='$\heartsuit$')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='$\heartsuit$')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petel&sepal  length of different iris flowers');

# %% [markdown]
# ##แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection="3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s=80*df2['PetalWidth'])

# %%
ax = plt.axes(projection="3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='sentosa')
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginiga')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petel&sepal  length of different iris flowers');

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa')
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor')
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![1_2c21SkzJMf3frPXPAR_gZA.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength']) #ดูการกระจายของ SepalLength (ความยาวกลีบเลี้ยง)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f2ae9fafe10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2aedff6190>,
#   <matplotlib.lines.Line2D at 0x7f2aee5f3c90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2aedcb2a50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2aedc79d50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f2ae9faf750>,
#   <matplotlib.lines.Line2D at 0x7f2ae9faf190>]}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False) # vert=False เปลี่ยนแนวกราฟ

# %%
ybp['medians'][0].get_ydata()
# Out:
# array([0.925, 1.075])

# %%
ybp['medians'][0].get_xdata()#ค่า midian
# Out:
# array([5.8, 5.8])

# %%
min(ybp['whiskers'][0].get_xdata()) #ดูค่า min
# Out:
# 4.3

# %%
max(ybp['whiskers'][1].get_xdata())
# Out:
# 7.9

# %%
ybp['caps'][1].get_xdata()
# Out:
# array([7.9, 7.9])

# %%
ybp['boxes'][0].get_xdata()
# Out:
# array([5.1, 5.1, 6.4, 6.4, 5.1])

# %%
ybp['boxes'][0].get_xdata()[0]
# Out:
# 5.1

# %%
max(ybp['whiskers'][0].get_xdata()) #ดูค่า Q1
# Out:
# 5.1

# %%
min(ybp['whiskers'][1].get_xdata()) #ค่า Q3
# Out:
# 6.4

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False,showmeans=True)

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline=True,showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f2ae9ffbfd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2ae9feefd0>,
#   <matplotlib.lines.Line2D at 0x7f2aea005550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2ae9fe5590>],
#  'means': [<matplotlib.lines.Line2D at 0x7f2ae9fe5050>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2aea005ad0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f2ae9fee550>,
#   <matplotlib.lines.Line2D at 0x7f2ae9feea90>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'$\heartsuit$'})
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f2ae99dc6d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2ae99e46d0>,
#   <matplotlib.lines.Line2D at 0x7f2ae99e4c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2ae99edbd0>],
#  'means': [<matplotlib.lines.Line2D at 0x7f2ae99ed710>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2ae99ed1d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f2ae99dcc10>,
#   <matplotlib.lines.Line2D at 0x7f2ae99e4190>]}

# %% [markdown]
# #Quiz กลุ่มfinal
# 1.เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3
#
# 2.วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %%
x=plt.boxplot(df['PetalLength']) #ดูการกระจายของ PetalLength

# %%
def box_vals(box_out_dict):
    Q1 = box_out_dict['boxes'][0].get_ydata()[0] 
    Q2 = box_out_dict['medians'][0].get_ydata()[0]
    Q3 = box_out_dict['boxes'][0].get_ydata()[2]
    IQR =  Q3 - Q1
    vmin =  box_out_dict['caps'][0].get_ydata()[0]
    vmax =  box_out_dict['caps'][1].get_ydata()[0] 
    return Q1,Q2,Q3,IQR,vmin,vmax

# %%
box_vals(x)
# Out:
# (1.6, 4.35, 5.1, 3.4999999999999996, 1.0, 6.9)
