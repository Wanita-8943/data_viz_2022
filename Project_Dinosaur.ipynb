# %% [markdown]
# <a href="https://colab.research.google.com/github/Wanita-8943/data_viz_2022/blob/main/Project_Dinosaur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Present Project กลุ่ม
#
# ไดร์ฟ
# https://drive.google.com/drive/u/0/folders/1G9XaOQ1IExr0m-UwWypqGPtGzi5HE-YL
# Dashboard
# https://datastudio.google.com/reporting/e45d8bb5-92ce-4fde-9775-7d1d568d7e6e
#
# ชุดข้อมูล
# https://datagov.mot.go.th/dataset/covid-19?fbclid=IwAR1UfKQlVXSW1kLfCBpTMHWx701sN_wAI1IRCWBucJgSQl8eJ0OVM2lJk0I

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Project_Dinosaur'

# %% [markdown]
# #data covid

# %% [markdown]
# * No รหัสผู้ป่วย
# * Age อายุของผู้ป่วย
# * Sex เพศผู้ป่วย
# * Nationality สัญชาติ
# * Province of isolation จังหวัดที่รักษาตัว
# * Notification Date วันที่กระทรวงได้รับรายงาน
# * Announce Date วันที่แถลงข่าว
# * Province of onset จังหวัดที่เริ่มพบว่าตัวเองมีอาการป่วย
# * District of onset อำเภอที่เริ่มพบว่าตัวเองมีอาการป่วย
# * risk สถานที่

# %% [markdown]
# ##ตารางข้อมูล covid ปี2020

# %%
data_covid2020 =  pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_covid2020
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %% [markdown]
# ##ตารางข้อมูล covid ปี2021(1)

# %%
data_covid2021_1 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-120864.csv'))
data_covid2021_1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ##ตารางข้อมูล covid ปี2021(2)

# %%
data_covid2021_2 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-271064.csv'))
data_covid2021_2
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454               NaN               NaN          NaN
# 1010455               NaN               NaN          NaN
# 1010456               NaN               NaN          NaN
# 1010457               NaN               NaN          NaN
# 1010458               NaN               NaN          NaN
#
# [1010459 rows x 12 columns]

# %% [markdown]
# ##ตารางข้อมูล covid ปี2022

# %%
data_covid2022 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-280265.csv'))
data_covid2022
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ##ต่อตาราง data_covid ทั้ง 4 ตาราง

# %%
data_covid = pd.concat([data_covid2020, data_covid2021_1, data_covid2021_2, data_covid2022])
data_covid
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  Unnamed: 11
# 0          กรุงเทพมหานคร               NaN          NaN
# 1          กรุงเทพมหานคร               NaN          NaN
# 2                 นครปฐม             เมือง          NaN
# 3          กรุงเทพมหานคร               NaN          NaN
# 4          กรุงเทพมหานคร               NaN          NaN
# ...                  ...               ...          ...
# 433548               NaN               NaN          NaN
# 433549               NaN               NaN          NaN
# 433550               NaN               NaN          NaN
# 433551               NaN               NaN          NaN
# 433552               NaN               NaN          NaN
#
# [3325951 rows x 12 columns]

# %% [markdown]
# ###เลือกเฉพาะ column ที่ต้องการ

# %%
covid = data_covid[['announce_date','province_of_isolation']]
covid
# Out:
#        announce_date province_of_isolation
# 0          12/1/2020         กรุงเทพมหานคร
# 1          17/1/2020         กรุงเทพมหานคร
# 2          22/1/2020                นครปฐม
# 3          22/1/2020         กรุงเทพมหานคร
# 4          24/1/2020               นนทบุรี
# ...              ...                   ...
# 433548     18/3/2022         กรุงเทพมหานคร
# 433549     18/3/2022         กรุงเทพมหานคร
# 433550     18/3/2022         กรุงเทพมหานคร
# 433551     18/3/2022                 สงขลา
# 433552     18/3/2022                 สงขลา
#
# [3325951 rows x 2 columns]

# %% [markdown]
# ##ตรวจสอบค่า Missing

# %%
covid.isnull().any() #ดูค่า missing ของแต่ละ column
# Out:
# announce_date            False
# province_of_isolation     True
# dtype: bool

# %% [markdown]
# ###จัดรูปแบบข้อมูล

# %%
len(set(covid['province_of_isolation'])) #ข้อมูลในคอลัมน์ province_of_isolation ต้องมี 77 ค่า
# Out:
# 81

# %%
set(covid['province_of_isolation'])
# Out:
# {nan,
#  'กทม',
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน'}

# %%
covid.replace({'กทม':'กรุงเทพมหานคร','ขอนแก่น\xa0':'ขอนแก่น','ภููเก็ต':'ภูเก็ต'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
len(set(covid['province_of_isolation'])) #มีค่าที่ชื่อว่า ไม่ระบุ
# Out:
# 78

# %%
covid.isnull().any()
# Out:
# announce_date            False
# province_of_isolation     True
# dtype: bool

# %%
Covid = covid.dropna() #drop ค่า Nan ออกจากตาราง

# %%
Covid
# Out:
#        announce_date province_of_isolation
# 0          12/1/2020         กรุงเทพมหานคร
# 1          17/1/2020         กรุงเทพมหานคร
# 2          22/1/2020                นครปฐม
# 3          22/1/2020         กรุงเทพมหานคร
# 4          24/1/2020               นนทบุรี
# ...              ...                   ...
# 433548     18/3/2022         กรุงเทพมหานคร
# 433549     18/3/2022         กรุงเทพมหานคร
# 433550     18/3/2022         กรุงเทพมหานคร
# 433551     18/3/2022                 สงขลา
# 433552     18/3/2022                 สงขลา
#
# [3321995 rows x 2 columns]

# %% [markdown]
# #สร้างตารางภูมิภาค

# %%
data_region = {'Province':['อำนาจเจริญ','บึงกาฬ','บุรีรัมย์','ชัยภูมิ','กาฬสินธุ์','ขอนแก่น','เลย','มหาสารคาม','มุกดาหาร','นครพนม','นครราชสีมา','หนองบัวลำภู','หนองคาย','ร้อยเอ็ด','สกลนคร','ศรีสะเกษ','สุรินทร์','อุบลราชธานี','อุดรธานี','ยโสธร','เชียงใหม่','เชียงราย','ลำปาง','ลำพูน','แม่ฮ่องสอน','น่าน','พะเยา','แพร่','อุตรดิตถ์','ตาก','สุโขทัย','พิษณุโลก','พิจิตร','กำแพงเพชร','เพชรบูรณ์','นครสวรรค์','อุทัยธานี','อ่างทอง','ชัยนาท','พระนครศรีอยุธยา','กรุงเทพมหานคร','ลพบุรี','นครปฐม','นนทบุรี','ปทุมธานี','สมุทรปราการ','สมุทรสาคร','สมุทรสงคราม','สระบุรี','สิงห์บุรี','สุพรรณบุรี','นครนายก','ฉะเชิงเทรา','จันทบุรี','ชลบุรี','ปราจีนบุรี','ระยอง','สระแก้ว','ตราด','กาญจนบุรี','ราชบุรี','เพชรบุรี','ประจวบคีรีขันธ์','ชุมพร','นครศรีธรรมราช','นราธิวาส','ปัตตานี','พัทลุง','สงขลา','สุราษฎร์ธานี','ยะลา','กระบี่','พังงา','ภูเก็ต','ระนอง','สตูล','ตรัง'],
             '6 ภูมิภาค':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],
}

# %%
data_region = pd.DataFrame.from_dict(data_region)
data_region
# Out:
#       Province           6 ภูมิภาค
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# ..         ...                 ...
# 72       พังงา                 ใต้
# 73      ภูเก็ต                 ใต้
# 74       ระนอง                 ใต้
# 75        สตูล                 ใต้
# 76        ตรัง                 ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ##รวมตาราง covid กับตาราง ภูมิภาค
# covid กับ data_region

# %%
covid_region = Covid.merge(data_region,how='left',left_on='province_of_isolation',right_on = 'Province') 
covid_region
# Out:
#         announce_date province_of_isolation       Province 6 ภูมิภาค
# 0           12/1/2020         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 1           17/1/2020         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 2           22/1/2020                นครปฐม         นครปฐม      กลาง
# 3           22/1/2020         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 4           24/1/2020               นนทบุรี        นนทบุรี      กลาง
# ...               ...                   ...            ...       ...
# 3321990     18/3/2022         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321991     18/3/2022         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321992     18/3/2022         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321993     18/3/2022                 สงขลา          สงขลา       ใต้
# 3321994     18/3/2022                 สงขลา          สงขลา       ใต้
#
# [3321995 rows x 4 columns]

# %% [markdown]
# ##ตรวจสอบค่า Missing

# %%
covid_region.isnull().any()
# Out:
# announce_date            False
# province_of_isolation    False
# Province                 False
# 6 ภูมิภาค                False
# dtype: bool

# %% [markdown]
# #นำเข้าข้อมูลที่เลือกเอง
# การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19
# ที่มา : https://datagov.mot.go.th/dataset/covid-19 (กระทรวงคมนาคม)

# %%
passenger =  pd.read_csv(os.path.join(path,'passenger-covid19.csv'))
passenger
# Out:
#         วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0     1/1/2020   1,483,255     885,353     272,578        102,678
# 1     2/1/2020   1,705,026   1,269,207     291,990        104,613
# 2     3/1/2020   1,752,572   1,366,412     301,260        100,575
# 3     4/1/2020   1,576,146   1,027,281     271,171        100,852
# 4     5/1/2020   1,565,134     915,425     254,176        100,784
# ..         ...         ...         ...         ...            ...
# 805  16/3/2022     641,639     685,639      81,496         50,761
# 806  17/3/2022     657,339     676,376      93,516         53,177
# 807  18/3/2022     646,203     729,250     104,801         63,230
# 808  19/3/2022     555,727     580,102      93,046         58,347
# 809  20/3/2022     495,000     455,593      84,072         64,442
#
#     รวมประชาชนเดินทาง (คน) รถส่วนบุคคล เข้า - ออก กทม. (คัน)  \
# 0                2,743,864                         2,310,406
# 1                3,370,836                         2,538,456
# 2                3,520,819                         2,649,091
# 3                2,975,450                         2,515,920
# 4                2,835,519                         2,542,483
# ..                     ...                               ...
# 805              1,459,535                         2,037,089
# 806              1,480,408                         2,127,054
# 807              1,543,484                         2,217,820
# 808              1,287,222                         2,049,811
# 809              1,099,107                         1,863,234
#
#     รถโดยสารประจำทางใน กทม. และปริมณฑล (ขสมก. และ รถร่วม) (คน)  \
# 0                                            1,249,925
# 1                                            1,452,127
# 2                                            1,526,841
# 3                                            1,359,227
# 4                                            1,330,523
# ..                                                 ...
# 805                                            608,499
# 806                                            624,531
# 807                                            610,545
# 808                                            521,037
# 809                                            459,263
#
#     รถโดยสารประจำทางระหว่าง กทม. - ตจว. \n(บขส. และ รถร่วม) (คน)  \
# 0                                              233,330
# 1                                              252,899
# 2                                              225,731
# 3                                              216,919
# 4                                              234,611
# ..                                                 ...
# 805                                             27,649
# 806                                             27,910
# 807                                             30,125
# 808                                             29,533
# 809                                             30,534
#
#     รถส่วนบุคคล เข้า - ออก กทม. (คัน).1  ... รถไฟระหว่างเมือง  \
# 0                             2,310,406  ...          115,975
# 1                             2,538,456  ...          103,113
# 2                             2,649,091  ...           98,657
# 3                             2,515,920  ...           94,876
# 4                             2,542,483  ...           98,259
# ..                                  ...  ...              ...
# 805                           2,037,089  ...           28,775
# 806                           2,127,054  ...           29,467
# 807                           2,217,820  ...           32,972
# 808                           2,049,811  ...           28,930
# 809                           1,863,234  ...           32,080
#
#     เรือด่วนเจ้าพระยา เรือคลองแสนแสบ เรือข้ามฟากเจ้าพระยา เรือไฟฟ้าเจ้าพระยา  \
# 0              29,518         20,420                    0                  0
# 1              30,794         35,430                    0                  0
# 2              31,036         32,540                    0                  0
# 3              20,236         20,850                    0                  0
# 4              17,066         20,030                    0                  0
# ..                ...            ...                  ...                ...
# 805             5,694          9,519               13,838                628
# 806             5,608          9,502               13,633                583
# 807             5,737          9,477               13,783                575
# 808             1,976          3,527               12,742                506
# 809                 0              0               12,375                358
#
#     เรือในภูมิภาค รวมท่าอากาศยานใน กทม. ท่าอากาศยานสุวรรณภูมิ  \
# 0         222,640                45,774                14,674
# 1         225,766                45,045                14,974
# 2         237,684                41,894                13,036
# 3         230,085                40,186                12,163
# 4         217,080                40,161                12,468
# ..            ...                   ...                   ...
# 805        51,817                23,360                11,176
# 806        64,190                26,329                12,579
# 807        75,229                29,725                14,085
# 808        74,295                27,474                13,272
# 809        71,339                28,736                13,659
#
#     ท่าอากาศยานดอนเมือง ท่าอากาศยานภูมิภาค
# 0                31,100             56,904
# 1                30,071             59,568
# 2                28,858             58,681
# 3                28,023             60,666
# 4                27,693             60,623
# ..                  ...                ...
# 805              12,184             27,401
# 806              13,750             26,848
# 807              15,640             33,505
# 808              14,202             30,873
# 809              15,077             35,706
#
# [810 rows x 28 columns]

# %% [markdown]
# ###เลือกเฉพาะ column ที่ต้องการ

# %%
Passenger = passenger[['วันที่','ทางถนน (คน)','ทางราง (คน)','ทางน้ำ (คน)', 'ทางอากาศ* (คน)', 'รวมประชาชนเดินทาง (คน)']]
Passenger
# Out:
#         วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0     1/1/2020   1,483,255     885,353     272,578        102,678
# 1     2/1/2020   1,705,026   1,269,207     291,990        104,613
# 2     3/1/2020   1,752,572   1,366,412     301,260        100,575
# 3     4/1/2020   1,576,146   1,027,281     271,171        100,852
# 4     5/1/2020   1,565,134     915,425     254,176        100,784
# ..         ...         ...         ...         ...            ...
# 805  16/3/2022     641,639     685,639      81,496         50,761
# 806  17/3/2022     657,339     676,376      93,516         53,177
# 807  18/3/2022     646,203     729,250     104,801         63,230
# 808  19/3/2022     555,727     580,102      93,046         58,347
# 809  20/3/2022     495,000     455,593      84,072         64,442
#
#     รวมประชาชนเดินทาง (คน)
# 0                2,743,864
# 1                3,370,836
# 2                3,520,819
# 3                2,975,450
# 4                2,835,519
# ..                     ...
# 805              1,459,535
# 806              1,480,408
# 807              1,543,484
# 808              1,287,222
# 809              1,099,107
#
# [810 rows x 6 columns]

# %% [markdown]
# ##ตรวจสอบค่า Missing

# %%
Passenger.isnull().any() #ดูค่า missing ของแต่ละ column
# Out:
# วันที่                    False
# ทางถนน (คน)               False
# ทางราง (คน)               False
# ทางน้ำ (คน)               False
# ทางอากาศ* (คน)            False
# รวมประชาชนเดินทาง (คน)    False
# dtype: bool

# %% [markdown]
# ##รวมตาราง covid_region กับตาราง Passenger

# %%
all_data = covid_region.merge(Passenger,how='left',left_on='announce_date',right_on='วันที่')
all_data
# Out:
#         announce_date province_of_isolation       Province 6 ภูมิภาค  \
# 0           12/1/2020         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 1           17/1/2020         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 2           22/1/2020                นครปฐม         นครปฐม      กลาง
# 3           22/1/2020         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 4           24/1/2020               นนทบุรี        นนทบุรี      กลาง
# ...               ...                   ...            ...       ...
# 3321990     18/3/2022         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321991     18/3/2022         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321992     18/3/2022         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321993     18/3/2022                 สงขลา          สงขลา       ใต้
# 3321994     18/3/2022                 สงขลา          สงขลา       ใต้
#
#             วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0        12/1/2020   1,511,236     988,051     246,025         99,755
# 1        17/1/2020   1,732,040   1,599,647     281,743        106,000
# 2        22/1/2020   1,678,182   1,488,097     267,105        101,432
# 3        22/1/2020   1,678,182   1,488,097     267,105        101,432
# 4        24/1/2020   1,658,692   1,527,329     281,291        103,697
# ...            ...         ...         ...         ...            ...
# 3321990  18/3/2022     646,203     729,250     104,801         63,230
# 3321991  18/3/2022     646,203     729,250     104,801         63,230
# 3321992  18/3/2022     646,203     729,250     104,801         63,230
# 3321993  18/3/2022     646,203     729,250     104,801         63,230
# 3321994  18/3/2022     646,203     729,250     104,801         63,230
#
#         รวมประชาชนเดินทาง (คน)
# 0                    2,845,067
# 1                    3,719,430
# 2                    3,534,816
# 3                    3,534,816
# 4                    3,571,009
# ...                        ...
# 3321990              1,543,484
# 3321991              1,543,484
# 3321992              1,543,484
# 3321993              1,543,484
# 3321994              1,543,484
#
# [3321995 rows x 10 columns]

# %% [markdown]
# ##ตรวจสอบค่า Missing

# %%
all_data.isnull().any() #ดูค่า missing ของแต่ละ column
# Out:
# announce_date             False
# province_of_isolation     False
# Province                  False
# 6 ภูมิภาค                 False
# วันที่                    False
# ทางถนน (คน)               False
# ทางราง (คน)               False
# ทางน้ำ (คน)               False
# ทางอากาศ* (คน)            False
# รวมประชาชนเดินทาง (คน)    False
# dtype: bool

# %% [markdown]
# ### เปลี่ยน datetime เพื่อที่จะแบ่งข้อมูลออกไปใช้งาน

# %%
import datetime
all_data = pd.DataFrame(all_data)
all_data['announce_date'] = pd.to_datetime(all_data['announce_date'], format = "%d/%m/%Y")
all_data
# Out:
#         announce_date province_of_isolation       Province 6 ภูมิภาค  \
# 0          2020-01-12         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 1          2020-01-17         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 2          2020-01-22                นครปฐม         นครปฐม      กลาง
# 3          2020-01-22         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 4          2020-01-24               นนทบุรี        นนทบุรี      กลาง
# ...               ...                   ...            ...       ...
# 3321990    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321991    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321992    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321993    2022-03-18                 สงขลา          สงขลา       ใต้
# 3321994    2022-03-18                 สงขลา          สงขลา       ใต้
#
#             วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0        12/1/2020   1,511,236     988,051     246,025         99,755
# 1        17/1/2020   1,732,040   1,599,647     281,743        106,000
# 2        22/1/2020   1,678,182   1,488,097     267,105        101,432
# 3        22/1/2020   1,678,182   1,488,097     267,105        101,432
# 4        24/1/2020   1,658,692   1,527,329     281,291        103,697
# ...            ...         ...         ...         ...            ...
# 3321990  18/3/2022     646,203     729,250     104,801         63,230
# 3321991  18/3/2022     646,203     729,250     104,801         63,230
# 3321992  18/3/2022     646,203     729,250     104,801         63,230
# 3321993  18/3/2022     646,203     729,250     104,801         63,230
# 3321994  18/3/2022     646,203     729,250     104,801         63,230
#
#         รวมประชาชนเดินทาง (คน)
# 0                    2,845,067
# 1                    3,719,430
# 2                    3,534,816
# 3                    3,534,816
# 4                    3,571,009
# ...                        ...
# 3321990              1,543,484
# 3321991              1,543,484
# 3321992              1,543,484
# 3321993              1,543,484
# 3321994              1,543,484
#
# [3321995 rows x 10 columns]

# %%
all_data.dtypes
# Out:
# announce_date             datetime64[ns]
# province_of_isolation             object
# Province                          object
# 6 ภูมิภาค                         object
# วันที่                            object
# ทางถนน (คน)                       object
# ทางราง (คน)                       object
# ทางน้ำ (คน)                       object
# ทางอากาศ* (คน)                    object
# รวมประชาชนเดินทาง (คน)            object
# dtype: object

# %%
all_data
# Out:
#         announce_date province_of_isolation       Province 6 ภูมิภาค  \
# 0          2020-01-12         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 1          2020-01-17         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 2          2020-01-22                นครปฐม         นครปฐม      กลาง
# 3          2020-01-22         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 4          2020-01-24               นนทบุรี        นนทบุรี      กลาง
# ...               ...                   ...            ...       ...
# 3321990    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321991    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321992    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321993    2022-03-18                 สงขลา          สงขลา       ใต้
# 3321994    2022-03-18                 สงขลา          สงขลา       ใต้
#
#             วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0        12/1/2020   1,511,236     988,051     246,025         99,755
# 1        17/1/2020   1,732,040   1,599,647     281,743        106,000
# 2        22/1/2020   1,678,182   1,488,097     267,105        101,432
# 3        22/1/2020   1,678,182   1,488,097     267,105        101,432
# 4        24/1/2020   1,658,692   1,527,329     281,291        103,697
# ...            ...         ...         ...         ...            ...
# 3321990  18/3/2022     646,203     729,250     104,801         63,230
# 3321991  18/3/2022     646,203     729,250     104,801         63,230
# 3321992  18/3/2022     646,203     729,250     104,801         63,230
# 3321993  18/3/2022     646,203     729,250     104,801         63,230
# 3321994  18/3/2022     646,203     729,250     104,801         63,230
#
#         รวมประชาชนเดินทาง (คน)
# 0                    2,845,067
# 1                    3,719,430
# 2                    3,534,816
# 3                    3,534,816
# 4                    3,571,009
# ...                        ...
# 3321990              1,543,484
# 3321991              1,543,484
# 3321992              1,543,484
# 3321993              1,543,484
# 3321994              1,543,484
#
# [3321995 rows x 10 columns]

# %% [markdown]
# ##แบ่งข้อมูลไปใช้งาน

# %%
covid2020 = all_data[(all_data['announce_date'] >= '2020-01-12') & (all_data['announce_date'] <= '2020-12-31')] #ข้อมูลปี 2020
covid2020
# Out:
#      announce_date province_of_isolation       Province 6 ภูมิภาค      วันที่  \
# 0       2020-01-12         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง   12/1/2020
# 1       2020-01-17         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง   17/1/2020
# 2       2020-01-22                นครปฐม         นครปฐม      กลาง   22/1/2020
# 3       2020-01-22         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง   22/1/2020
# 4       2020-01-24               นนทบุรี        นนทบุรี      กลาง   24/1/2020
# ...            ...                   ...            ...       ...         ...
# 6858    2020-12-31                 ระยอง          ระยอง  ตะวันออก  31/12/2020
# 6859    2020-12-31                 ระยอง          ระยอง  ตะวันออก  31/12/2020
# 6860    2020-12-31                 ระยอง          ระยอง  ตะวันออก  31/12/2020
# 6861    2020-12-31                 ระยอง          ระยอง  ตะวันออก  31/12/2020
# 6862    2020-12-31                 ระยอง          ระยอง  ตะวันออก  31/12/2020
#
#      ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน) รวมประชาชนเดินทาง (คน)
# 0      1,511,236     988,051     246,025         99,755              2,845,067
# 1      1,732,040   1,599,647     281,743        106,000              3,719,430
# 2      1,678,182   1,488,097     267,105        101,432              3,534,816
# 3      1,678,182   1,488,097     267,105        101,432              3,534,816
# 4      1,658,692   1,527,329     281,291        103,697              3,571,009
# ...          ...         ...         ...            ...                    ...
# 6858     657,630     397,023     142,755         59,777              1,257,185
# 6859     657,630     397,023     142,755         59,777              1,257,185
# 6860     657,630     397,023     142,755         59,777              1,257,185
# 6861     657,630     397,023     142,755         59,777              1,257,185
# 6862     657,630     397,023     142,755         59,777              1,257,185
#
# [6862 rows x 10 columns]

# %%
covid2021_1 = all_data[(all_data['announce_date'] >= '2021-01-01') & (all_data['announce_date'] <= '2021-03-31')] #ข้อมูลไตรมาสแรกของปี 2021
covid2021_1
# Out:
#       announce_date province_of_isolation       Province 6 ภูมิภาค     วันที่  \
# 120      2021-03-06              ปทุมธานี       ปทุมธานี      กลาง   6/3/2021
# 6863     2021-01-01         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง   1/1/2021
# 6864     2021-01-01              ปทุมธานี       ปทุมธานี      กลาง   1/1/2021
# 6865     2021-01-01                นครปฐม         นครปฐม      กลาง   1/1/2021
# 6866     2021-01-01             สมุทรสาคร      สมุทรสาคร      กลาง   1/1/2021
# ...             ...                   ...            ...       ...        ...
# 28727    2021-03-31         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง  31/3/2021
# 28728    2021-03-31         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง  31/3/2021
# 28729    2021-03-31                   ตาก            ตาก   ตะวันตก  31/3/2021
# 28730    2021-03-31                   ตาก            ตาก   ตะวันตก  31/3/2021
# 28731    2021-03-31              นราธิวาส       นราธิวาส       ใต้  31/3/2021
#
#       ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 120       862,101     682,272      98,061         47,995
# 6863      629,297     331,738     132,198         53,527
# 6864      629,297     331,738     132,198         53,527
# 6865      629,297     331,738     132,198         53,527
# 6866      629,297     331,738     132,198         53,527
# ...           ...         ...         ...            ...
# 28727     982,425   1,039,196     110,500         57,980
# 28728     982,425   1,039,196     110,500         57,980
# 28729     982,425   1,039,196     110,500         57,980
# 28730     982,425   1,039,196     110,500         57,980
# 28731     982,425   1,039,196     110,500         57,980
#
#       รวมประชาชนเดินทาง (คน)
# 120                1,690,429
# 6863               1,146,760
# 6864               1,146,760
# 6865               1,146,760
# 6866               1,146,760
# ...                      ...
# 28727              2,190,101
# 28728              2,190,101
# 28729              2,190,101
# 28730              2,190,101
# 28731              2,190,101
#
# [21870 rows x 10 columns]

# %%
covid2021_2 = all_data[(all_data['announce_date'] >= '2021-04-01') & (all_data['announce_date'] <= '2021-06-30')] #ข้อมูลไตรมาสสองของปี 2021
covid2021_2
# Out:
#        announce_date province_of_isolation   Province 6 ภูมิภาค     วันที่  \
# 28732     2021-04-01             สมุทรสาคร  สมุทรสาคร      กลาง   1/4/2021
# 28733     2021-04-01             สมุทรสาคร  สมุทรสาคร      กลาง   1/4/2021
# 28734     2021-04-01             สมุทรสาคร  สมุทรสาคร      กลาง   1/4/2021
# 28735     2021-04-01             สมุทรสาคร  สมุทรสาคร      กลาง   1/4/2021
# 28736     2021-04-01             สมุทรสาคร  สมุทรสาคร      กลาง   1/4/2021
# ...              ...                   ...        ...       ...        ...
# 259024    2021-06-30                 สงขลา      สงขลา       ใต้  30/6/2021
# 259025    2021-06-30                 สงขลา      สงขลา       ใต้  30/6/2021
# 259026    2021-06-30                 สงขลา      สงขลา       ใต้  30/6/2021
# 259027    2021-06-30                 สงขลา      สงขลา       ใต้  30/6/2021
# 259028    2021-06-30                 สงขลา      สงขลา       ใต้  30/6/2021
#
#        ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 28732    1,002,983   1,037,660     102,982         70,353
# 28733    1,002,983   1,037,660     102,982         70,353
# 28734    1,002,983   1,037,660     102,982         70,353
# 28735    1,002,983   1,037,660     102,982         70,353
# 28736    1,002,983   1,037,660     102,982         70,353
# ...            ...         ...         ...            ...
# 259024     572,766     462,742      57,948         14,543
# 259025     572,766     462,742      57,948         14,543
# 259026     572,766     462,742      57,948         14,543
# 259027     572,766     462,742      57,948         14,543
# 259028     572,766     462,742      57,948         14,543
#
#        รวมประชาชนเดินทาง (คน)
# 28732               2,213,978
# 28733               2,213,978
# 28734               2,213,978
# 28735               2,213,978
# 28736               2,213,978
# ...                       ...
# 259024              1,107,999
# 259025              1,107,999
# 259026              1,107,999
# 259027              1,107,999
# 259028              1,107,999
#
# [230297 rows x 10 columns]

# %%
covid2021_3 = all_data[(all_data['announce_date'] >= '2021-07-01') & (all_data['announce_date'] <= '2021-09-30')] #ข้อมูลไตรมาสสามของปี 2021
covid2021_3
# Out:
#         announce_date province_of_isolation      Province 6 ภูมิภาค  \
# 259029     2021-07-01              เชียงราย      เชียงราย     เหนือ
# 259030     2021-07-01              เชียงราย      เชียงราย     เหนือ
# 259031     2021-07-01              เชียงราย      เชียงราย     เหนือ
# 259032     2021-07-01              เชียงราย      เชียงราย     เหนือ
# 259033     2021-07-01              เชียงราย      เชียงราย     เหนือ
# ...               ...                   ...           ...       ...
# 1625980    2021-09-30              เพชรบุรี      เพชรบุรี   ตะวันตก
# 1625981    2021-09-30                  ตรัง          ตรัง       ใต้
# 1625982    2021-09-30                  ตรัง          ตรัง       ใต้
# 1625983    2021-09-30          สุราษฎร์ธานี  สุราษฎร์ธานี       ใต้
# 1625984    2021-09-30                 สงขลา         สงขลา       ใต้
#
#             วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 259029    1/7/2021     574,401     447,352      50,212         13,123
# 259030    1/7/2021     574,401     447,352      50,212         13,123
# 259031    1/7/2021     574,401     447,352      50,212         13,123
# 259032    1/7/2021     574,401     447,352      50,212         13,123
# 259033    1/7/2021     574,401     447,352      50,212         13,123
# ...            ...         ...         ...         ...            ...
# 1625980  30/9/2021     470,121     436,644      50,612          9,821
# 1625981  30/9/2021     470,121     436,644      50,612          9,821
# 1625982  30/9/2021     470,121     436,644      50,612          9,821
# 1625983  30/9/2021     470,121     436,644      50,612          9,821
# 1625984  30/9/2021     470,121     436,644      50,612          9,821
#
#         รวมประชาชนเดินทาง (คน)
# 259029               1,085,088
# 259030               1,085,088
# 259031               1,085,088
# 259032               1,085,088
# 259033               1,085,088
# ...                        ...
# 1625980                967,198
# 1625981                967,198
# 1625982                967,198
# 1625983                967,198
# 1625984                967,198
#
# [1366956 rows x 10 columns]

# %%
covid2021_4 = all_data[(all_data['announce_date'] >= '2021-10-01') & (all_data['announce_date'] <= '2021-12-31')] #ข้อมูลไตรมาสสี่ของปี 2021
covid2021_4
# Out:
#         announce_date province_of_isolation       Province 6 ภูมิภาค  \
# 1625985    2021-10-01                 พะเยา          พะเยา     เหนือ
# 1625986    2021-10-01                 พะเยา          พะเยา     เหนือ
# 1625987    2021-10-01              เชียงราย       เชียงราย     เหนือ
# 1625988    2021-10-01              เชียงราย       เชียงราย     เหนือ
# 1625989    2021-10-01              เชียงราย       เชียงราย     เหนือ
# ...               ...                   ...            ...       ...
# 2242256    2021-12-31                 ระนอง          ระนอง       ใต้
# 2242257    2021-12-31                  สตูล           สตูล       ใต้
# 2242258    2021-12-31              ปทุมธานี       ปทุมธานี      กลาง
# 2242259    2021-12-31         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 2242260    2021-12-31         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
#
#              วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 1625985   1/10/2021     542,326     485,393      51,797         19,117
# 1625986   1/10/2021     542,326     485,393      51,797         19,117
# 1625987   1/10/2021     542,326     485,393      51,797         19,117
# 1625988   1/10/2021     542,326     485,393      51,797         19,117
# 1625989   1/10/2021     542,326     485,393      51,797         19,117
# ...             ...         ...         ...         ...            ...
# 2242256  31/12/2021     563,961     536,918     162,259         60,894
# 2242257  31/12/2021     563,961     536,918     162,259         60,894
# 2242258  31/12/2021     563,961     536,918     162,259         60,894
# 2242259  31/12/2021     563,961     536,918     162,259         60,894
# 2242260  31/12/2021     563,961     536,918     162,259         60,894
#
#         รวมประชาชนเดินทาง (คน)
# 1625985              1,098,633
# 1625986              1,098,633
# 1625987              1,098,633
# 1625988              1,098,633
# 1625989              1,098,633
# ...                        ...
# 2242256              1,324,032
# 2242257              1,324,032
# 2242258              1,324,032
# 2242259              1,324,032
# 2242260              1,324,032
#
# [616276 rows x 10 columns]

# %%
covid2022_1 = all_data[(all_data['announce_date'] >= '2022-01-01') & (all_data['announce_date'] <= '2022-01-31')] #ข้อมูลเดือนมกราคมปี 2022
covid2022_1
# Out:
#         announce_date province_of_isolation       Province  \
# 2242261    2022-01-01                 พะเยา          พะเยา
# 2242262    2022-01-01                 พะเยา          พะเยา
# 2242263    2022-01-01                 พะเยา          พะเยา
# 2242264    2022-01-01                 พะเยา          พะเยา
# 2242265    2022-01-01                 พะเยา          พะเยา
# ...               ...                   ...            ...
# 2459363    2022-01-31               ขอนแก่น        ขอนแก่น
# 2459364    2022-01-31         กรุงเทพมหานคร  กรุงเทพมหานคร
# 2459365    2022-01-31         กรุงเทพมหานคร  กรุงเทพมหานคร
# 2459366    2022-01-31         กรุงเทพมหานคร  กรุงเทพมหานคร
# 2459367    2022-01-31         กรุงเทพมหานคร  กรุงเทพมหานคร
#
#                   6 ภูมิภาค     วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน)  \
# 2242261               เหนือ   1/1/2022     515,514     411,352     151,399
# 2242262               เหนือ   1/1/2022     515,514     411,352     151,399
# 2242263               เหนือ   1/1/2022     515,514     411,352     151,399
# 2242264               เหนือ   1/1/2022     515,514     411,352     151,399
# 2242265               เหนือ   1/1/2022     515,514     411,352     151,399
# ...                     ...        ...         ...         ...         ...
# 2459363  ตะวันออกเฉียงเหนือ  31/1/2022     699,417     700,021      96,378
# 2459364                กลาง  31/1/2022     699,417     700,021      96,378
# 2459365                กลาง  31/1/2022     699,417     700,021      96,378
# 2459366                กลาง  31/1/2022     699,417     700,021      96,378
# 2459367                กลาง  31/1/2022     699,417     700,021      96,378
#
#         ทางอากาศ* (คน) รวมประชาชนเดินทาง (คน)
# 2242261         56,701              1,134,966
# 2242262         56,701              1,134,966
# 2242263         56,701              1,134,966
# 2242264         56,701              1,134,966
# 2242265         56,701              1,134,966
# ...                ...                    ...
# 2459363         52,016              1,547,832
# 2459364         52,016              1,547,832
# 2459365         52,016              1,547,832
# 2459366         52,016              1,547,832
# 2459367         52,016              1,547,832
#
# [217107 rows x 10 columns]

# %%
covid2022_2 = all_data[(all_data['announce_date'] >= '2022-02-01') & (all_data['announce_date'] <= '2022-02-28')] #ข้อมูลเดือนกุมภาพันธ์ปี 2022
covid2022_2
# Out:
#         announce_date province_of_isolation   Province 6 ภูมิภาค     วันที่  \
# 2459368    2022-02-01                 พะเยา      พะเยา     เหนือ   1/2/2022
# 2459369    2022-02-01                 พะเยา      พะเยา     เหนือ   1/2/2022
# 2459370    2022-02-01                 พะเยา      พะเยา     เหนือ   1/2/2022
# 2459371    2022-02-01                 พะเยา      พะเยา     เหนือ   1/2/2022
# 2459372    2022-02-01                 พะเยา      พะเยา     เหนือ   1/2/2022
# ...               ...                   ...        ...       ...        ...
# 2910748    2022-02-28              ปทุมธานี   ปทุมธานี      กลาง  28/2/2022
# 2910749    2022-02-28             นครสวรรค์  นครสวรรค์      กลาง  28/2/2022
# 2910750    2022-02-28             นครสวรรค์  นครสวรรค์      กลาง  28/2/2022
# 2910751    2022-02-28             นครสวรรค์  นครสวรรค์      กลาง  28/2/2022
# 2910752    2022-02-28             นครสวรรค์  นครสวรรค์      กลาง  28/2/2022
#
#         ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 2459368     714,901     745,660      99,446         38,761
# 2459369     714,901     745,660      99,446         38,761
# 2459370     714,901     745,660      99,446         38,761
# 2459371     714,901     745,660      99,446         38,761
# 2459372     714,901     745,660      99,446         38,761
# ...             ...         ...         ...            ...
# 2910748     669,958     687,896      85,381         51,364
# 2910749     669,958     687,896      85,381         51,364
# 2910750     669,958     687,896      85,381         51,364
# 2910751     669,958     687,896      85,381         51,364
# 2910752     669,958     687,896      85,381         51,364
#
#         รวมประชาชนเดินทาง (คน)
# 2459368              1,598,768
# 2459369              1,598,768
# 2459370              1,598,768
# 2459371              1,598,768
# 2459372              1,598,768
# ...                        ...
# 2910748              1,494,599
# 2910749              1,494,599
# 2910750              1,494,599
# 2910751              1,494,599
# 2910752              1,494,599
#
# [451385 rows x 10 columns]

# %%
covid2022_3 = all_data[all_data['announce_date'] >= '2022-03-01'] #ข้อมูลวันที่ 1- 18 เดือนมีนาคม ปี 2022
covid2022_3
# Out:
#         announce_date province_of_isolation       Province 6 ภูมิภาค  \
# 2910753    2022-03-01            แม่ฮ่องสอน     แม่ฮ่องสอน     เหนือ
# 2910754    2022-03-01            แม่ฮ่องสอน     แม่ฮ่องสอน     เหนือ
# 2910755    2022-03-01            แม่ฮ่องสอน     แม่ฮ่องสอน     เหนือ
# 2910756    2022-03-01            แม่ฮ่องสอน     แม่ฮ่องสอน     เหนือ
# 2910757    2022-03-01             เชียงใหม่      เชียงใหม่     เหนือ
# ...               ...                   ...            ...       ...
# 3321990    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321991    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321992    2022-03-18         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 3321993    2022-03-18                 สงขลา          สงขลา       ใต้
# 3321994    2022-03-18                 สงขลา          สงขลา       ใต้
#
#             วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 2910753   1/3/2022     666,637     696,843      83,386         41,226
# 2910754   1/3/2022     666,637     696,843      83,386         41,226
# 2910755   1/3/2022     666,637     696,843      83,386         41,226
# 2910756   1/3/2022     666,637     696,843      83,386         41,226
# 2910757   1/3/2022     666,637     696,843      83,386         41,226
# ...            ...         ...         ...         ...            ...
# 3321990  18/3/2022     646,203     729,250     104,801         63,230
# 3321991  18/3/2022     646,203     729,250     104,801         63,230
# 3321992  18/3/2022     646,203     729,250     104,801         63,230
# 3321993  18/3/2022     646,203     729,250     104,801         63,230
# 3321994  18/3/2022     646,203     729,250     104,801         63,230
#
#         รวมประชาชนเดินทาง (คน)
# 2910753              1,488,092
# 2910754              1,488,092
# 2910755              1,488,092
# 2910756              1,488,092
# 2910757              1,488,092
# ...                        ...
# 3321990              1,543,484
# 3321991              1,543,484
# 3321992              1,543,484
# 3321993              1,543,484
# 3321994              1,543,484
#
# [411242 rows x 10 columns]

# %% [markdown]
# ##เลือกทำข้อมูลวันที่ 29 ธันวาคม 2021 - 4 มกราคม 2022
# ซึ่งเป็นข้อมูล 7 วันอันตรายช่วงปีใหม่

# %% [markdown]
# ###ทำการ Groupby เพื่อดูจำนวนผู้รักษาตัวสะสมของแต่ละจังหวัด ตั้งแต่วันที่ 29 ธันวาคม 2021 - 4 มกราคม 2022

# %%
datacovid = all_data[(all_data['announce_date'] >= '2021-12-29') & (all_data['announce_date'] <= '2022-01-04')]
datacovid
# Out:
#         announce_date province_of_isolation       Province 6 ภูมิภาค  \
# 2233538    2021-12-29                  น่าน           น่าน     เหนือ
# 2233539    2021-12-29                  น่าน           น่าน     เหนือ
# 2233540    2021-12-29                  น่าน           น่าน     เหนือ
# 2233541    2021-12-29                  น่าน           น่าน     เหนือ
# 2233542    2021-12-29                  น่าน           น่าน     เหนือ
# ...               ...                   ...            ...       ...
# 2254397    2022-01-04         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 2254398    2022-01-04         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 2254399    2022-01-04         กรุงเทพมหานคร  กรุงเทพมหานคร      กลาง
# 2254400    2022-01-04              พิษณุโลก       พิษณุโลก      กลาง
# 2254401    2022-01-04         นครศรีธรรมราช  นครศรีธรรมราช       ใต้
#
#              วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 2233538  29/12/2021     754,823     708,014     131,275         65,842
# 2233539  29/12/2021     754,823     708,014     131,275         65,842
# 2233540  29/12/2021     754,823     708,014     131,275         65,842
# 2233541  29/12/2021     754,823     708,014     131,275         65,842
# 2233542  29/12/2021     754,823     708,014     131,275         65,842
# ...             ...         ...         ...         ...            ...
# 2254397    4/1/2022     707,593     658,361      89,162         55,575
# 2254398    4/1/2022     707,593     658,361      89,162         55,575
# 2254399    4/1/2022     707,593     658,361      89,162         55,575
# 2254400    4/1/2022     707,593     658,361      89,162         55,575
# 2254401    4/1/2022     707,593     658,361      89,162         55,575
#
#         รวมประชาชนเดินทาง (คน)
# 2233538              1,659,954
# 2233539              1,659,954
# 2233540              1,659,954
# 2233541              1,659,954
# 2233542              1,659,954
# ...                        ...
# 2254397              1,510,691
# 2254398              1,510,691
# 2254399              1,510,691
# 2254400              1,510,691
# 2254401              1,510,691
#
# [20864 rows x 10 columns]

# %%
gb_datacovid = datacovid.groupby(['announce_date','province_of_isolation']).size().reset_index(name='จำนวนผู้รักษาตัว')
gb_datacovid
# Out:
#     announce_date province_of_isolation  จำนวนผู้รักษาตัว
# 0      2021-12-29                กระบี่                37
# 1      2021-12-29         กรุงเทพมหานคร               407
# 2      2021-12-29             กาญจนบุรี                28
# 3      2021-12-29             กาฬสินธุ์                65
# 4      2021-12-29             กำแพงเพชร                12
# ..            ...                   ...               ...
# 522    2022-01-04              เพชรบุรี                 3
# 523    2022-01-04             เพชรบูรณ์                23
# 524    2022-01-04                   เลย                 5
# 525    2022-01-04                  แพร่                10
# 526    2022-01-04            แม่ฮ่องสอน                10
#
# [527 rows x 3 columns]

# %%
alldata = datacovid.merge(gb_datacovid,how='left',left_on='province_of_isolation',right_on = 'province_of_isolation') 
alldata
# Out:
#        announce_date_x province_of_isolation       Province 6 ภูมิภาค  \
# 0           2021-12-29                  น่าน           น่าน     เหนือ
# 1           2021-12-29                  น่าน           น่าน     เหนือ
# 2           2021-12-29                  น่าน           น่าน     เหนือ
# 3           2021-12-29                  น่าน           น่าน     เหนือ
# 4           2021-12-29                  น่าน           น่าน     เหนือ
# ...                ...                   ...            ...       ...
# 145743      2022-01-04         นครศรีธรรมราช  นครศรีธรรมราช       ใต้
# 145744      2022-01-04         นครศรีธรรมราช  นครศรีธรรมราช       ใต้
# 145745      2022-01-04         นครศรีธรรมราช  นครศรีธรรมราช       ใต้
# 145746      2022-01-04         นครศรีธรรมราช  นครศรีธรรมราช       ใต้
# 145747      2022-01-04         นครศรีธรรมราช  นครศรีธรรมราช       ใต้
#
#             วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0       29/12/2021     754,823     708,014     131,275         65,842
# 1       29/12/2021     754,823     708,014     131,275         65,842
# 2       29/12/2021     754,823     708,014     131,275         65,842
# 3       29/12/2021     754,823     708,014     131,275         65,842
# 4       29/12/2021     754,823     708,014     131,275         65,842
# ...            ...         ...         ...         ...            ...
# 145743    4/1/2022     707,593     658,361      89,162         55,575
# 145744    4/1/2022     707,593     658,361      89,162         55,575
# 145745    4/1/2022     707,593     658,361      89,162         55,575
# 145746    4/1/2022     707,593     658,361      89,162         55,575
# 145747    4/1/2022     707,593     658,361      89,162         55,575
#
#        รวมประชาชนเดินทาง (คน) announce_date_y  จำนวนผู้รักษาตัว
# 0                   1,659,954      2021-12-29                16
# 1                   1,659,954      2021-12-30                 9
# 2                   1,659,954      2021-12-31                 8
# 3                   1,659,954      2022-01-01                18
# 4                   1,659,954      2022-01-02                17
# ...                       ...             ...               ...
# 145743              1,510,691      2021-12-31               103
# 145744              1,510,691      2022-01-01               161
# 145745              1,510,691      2022-01-02               128
# 145746              1,510,691      2022-01-03                96
# 145747              1,510,691      2022-01-04                81
#
# [145748 rows x 12 columns]

# %% [markdown]
# #โหลดข้อมูลออกไปใช้งาน

# %%
alldata.to_csv('alldata.csv',index=False)
